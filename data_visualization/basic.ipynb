# %%
import matplotlib.pyplot as plt

# %%
plt.plot(5, 5, 'o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# if using this line, we can easily add a title for example to the axes after the plot was rendered, 
# without need to regenerate the figure.
# %matplotlib notebook

# %%
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Plotting Example')
# Out:
# Text(0.5, 1.0, 'Plotting Example')

# %%
# Pandas has a built-in implementation of it.
# Therefore, plotting in pandas is as simple as calling the plot function on a given pandas series or dataframe.
